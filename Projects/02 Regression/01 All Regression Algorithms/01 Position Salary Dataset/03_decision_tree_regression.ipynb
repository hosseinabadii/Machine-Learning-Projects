# %% [markdown]
# # Decision Tree Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('data/Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
y_pred = regressor.predict([[6.5]])
print(f"Prediction with Decision Tree: {y_pred[0]}")
# Out:
# Prediction with Decision Tree: 150000.0

# %% [markdown]
# ## Visualising the Decision Tree Regression results

# %%
X_grid = np.arange(X.min(), X.max(), 0.01)
X_grid = X_grid.reshape(-1, 1)
plt.scatter(X, y, color="red", label="Real")
plt.plot(X_grid, regressor.predict(X_grid), color="blue", label="Predicted")
plt.title("Decision Tree Regression")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.legend()
plt.show()
